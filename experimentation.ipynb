# %% [markdown]
# <div style = "text-align: left"><font size = 8 color = "#B22222" face = "verdana"><b>Tesco Telco</b></font></div>

# %% [markdown]
# <div style = "text-align: left"><font size = 6 color = "#00008B" face = "verdana"><b>Red Zone Project - Experimentation</b></font></div>
# <div style = "text-align: leftt"><font><i>By 'Olatubosun Osanyinro</i></font></div>
# <div style = "text-align: leftt"><font>18th February 2023</font></div>

# %% [markdown]
# ## Data Ingestion

# %%
import os
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\User\\Documents\\datahackerman_rzproject\\tesco_telco_prediction'

# %%
FILE_NAME = "Churn.csv"
DATA_FOLDER = "data"

# %%
main_path = os.getcwd()
main_path
# Out:
# 'C:\\Users\\User\\Documents\\datahackerman_rzproject\\tesco_telco_prediction'

# %%
file_path = os.path.join(os.path.join(main_path, DATA_FOLDER), FILE_NAME)

# %%
file_path
# Out:
# 'C:\\Users\\User\\Documents\\datahackerman_rzproject\\tesco_telco_prediction\\data\\Churn.csv'

# %%
# %%time

Churn_data = pd.read_csv(file_path)
# Out:
# CPU times: total: 31.2 ms
# Wall time: 77.3 ms

# %%
Churn_data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
Churn_data.shape
# Out:
# (7043, 21)

# %% [markdown]
# ## Data Inspection

# %%
Churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
Churn_data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# ## Exploration Data Analysis

# %% [markdown]
# ### Model Building

# %%
Churn_data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ### Train Test Split

# %%
# 0.3, 0.7

# %%
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
# y = mX + c

# %%
X = Churn_data[["customerID", "gender", "SeniorCitizen", "Partner", "Dependents", "tenure"]]

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure
# 0  7590-VHVEG  Female              0     Yes         No       1
# 1  5575-GNVDE    Male              0      No         No      34
# 2  3668-QPYBK    Male              0      No         No       2
# 3  7795-CFOCW    Male              0      No         No      45
# 4  9237-HQITU  Female              0      No         No       2

# %%
y = Churn_data["tenure"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 y = Churn_data["tenure"]
#
# NameError: name 'Churn_data' is not defined

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
y[0:5]
# Out:
# 0     1
# 1    34
# 2     2
# 3    45
# 4     2
# Name: tenure, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((4718, 6), (2325, 6))

# %%
train_data, test_data = train_test_split(Churn_data, test_size=0.33, random_state=42)

# %%
train_data.shape, test_data.shape
# Out:
# ((4718, 21), (2325, 21))

# %%
train_data.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 298   2985-JUUBZ    Male              0     Yes        Yes      40
# 3318  5016-ETTFF    Male              0      No         No      10
# 5586  1998-VHJHK  Female              0      No         No      27
# 6654  1925-TIBLE  Female              0     Yes         No       7
# 5362  0485-ZBSLN    Male              0     Yes        Yes      65
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 298           Yes               Yes             DSL                   No  ...
# 3318           No  No phone service             DSL                   No  ...
# 5586          Yes                No              No  No internet service  ...
# 6654          Yes               Yes     Fiber optic                   No  ...
# 5362          Yes               Yes              No  No internet service  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
test_data.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 185   1024-GUALD  Female              0     Yes         No       1
# 2715  0484-JPBRU    Male              0      No         No      41
# 3825  3620-EHIMZ  Female              0     Yes        Yes      52
# 1807  6910-HADCM  Female              0      No         No       1
# 132   8587-XYZSF    Male              0      No         No      67
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 185            No  No phone service             DSL                   No  ...
# 2715          Yes               Yes              No  No internet service  ...
# 3825          Yes                No              No  No internet service  ...
# 1807          Yes                No     Fiber optic                   No  ...
# 132           Yes                No             DSL                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
label = 'tenure'
print("Summary of class variable: \n", train_data[label].describe())
# Out:
# Summary of class variable:
#  count    4718.000000
# mean       32.465028
# std        24.513523
# min         0.000000
# 25%         9.000000
# 50%        29.000000
# 75%        55.000000
# max        72.000000
# Name: tenure, dtype: float64

# %%
save_path = 'models'
predictor = TabularPredictor(label=label, path=save_path).fit(train_data)
# Out:
# ...
# Beginning AutoGluon training ...
# AutoGluon will save models to "models\"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.16
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22621
# Train Data Rows:    4718
# Train Data Columns: 20
# Label Column: tenure
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == int, but few unique label-values observed).
# 	First 10 (of 73) unique label values:  [40, 10, 27, 7, 65, 23, 47, 11, 12, 30]
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# ...
# Fraction of data from classes with at least 10 examples that will be kept for training models: 0.9983043662568886
# Train Data Class Count: 72
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# ...

# %%
predictor.leaderboard(silent=True)
# Out:
#                   model  score_val  pred_time_val     fit_time  \
# 0   WeightedEnsemble_L2      0.166       0.144760  2018.518593
# 1              CatBoost      0.158       0.015783  2000.234030
# 2        NeuralNetTorch      0.154       0.007982     6.254023
# 3               XGBoost      0.146       0.015637    11.296911
# 4            LightGBMXT      0.140       0.015626    14.922478
# 5       NeuralNetFastAI      0.140       0.024673     5.123429
# 6              LightGBM      0.130       0.017574    13.899136
# 7      RandomForestGini      0.122       0.040679     6.850252
# 8        ExtraTreesGini      0.118       0.089621     1.941670
# 9      RandomForestEntr      0.116       0.062725     2.044237
# 10        LightGBMLarge      0.112       0.015626    36.434902
# 11       ExtraTreesEntr      0.106       0.123610     1.920373
# 12       KNeighborsUnif      0.068       0.031375     9.586771
# 13       KNeighborsDist      0.056       0.017462     0.006005
#
# ...

# %% [markdown]
# ## Model Evaluation

# %%
test_data.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 185   1024-GUALD  Female              0     Yes         No       1
# 2715  0484-JPBRU    Male              0      No         No      41
# 3825  3620-EHIMZ  Female              0     Yes        Yes      52
# 1807  6910-HADCM  Female              0      No         No       1
# 132   8587-XYZSF    Male              0      No         No      67
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 185            No  No phone service             DSL                   No  ...
# 2715          Yes               Yes              No  No internet service  ...
# 3825          Yes                No              No  No internet service  ...
# 1807          Yes                No     Fiber optic                   No  ...
# 132           Yes                No             DSL                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
y_test = test_data[label]  # values to predict

# %%
y_test[0:5]
# Out:
# 185      1
# 2715    41
# 3825    52
# 1807     1
# 132     67
# Name: tenure, dtype: int64

# %%
test_data_nolab = test_data.drop(columns=[label])  # delete label column to prove we're not cheating
test_data_nolab.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents PhoneService  \
# 185   1024-GUALD  Female              0     Yes         No           No
# 2715  0484-JPBRU    Male              0      No         No          Yes
# 3825  3620-EHIMZ  Female              0     Yes        Yes          Yes
# 1807  6910-HADCM  Female              0      No         No          Yes
# 132   8587-XYZSF    Male              0      No         No          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 185   No phone service             DSL                   No
# 2715               Yes              No  No internet service
# 3825                No              No  No internet service
# 1807                No     Fiber optic                   No
# 132                 No             DSL                   No
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 185                    No                   No                   No
# ...

# %%
save_path
# Out:
# 'models'

# %% [markdown]
# Now, load in the stored models.

# %%
predictor

# %%
save_model_predictor = TabularPredictor.load(save_path)

# %%
save_model_predictor

# %%
y_pred = save_model_predictor.predict(test_data_nolab)

# %%
y_pred[0:5]
# Out:
# 185      1
# 2715     7
# 3825    18
# 1807     1
# 132     39
# Name: tenure, dtype: int64

# %%
print("Predictions:  \n", y_pred)
perf = save_model_predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: accuracy on test data: 0.1410752688172043
# Evaluations on test data:
# {
#     "accuracy": 0.1410752688172043,
#     "balanced_accuracy": 0.03343671972945924,
#     "mcc": 0.10480212445327368
# }
# Predictions:
#  185      1
# 2715     7
# 3825    18
# 1807     1
# 132     39
#         ..
# 4147    72
# 3542    70
# 3759     5
# 1114    49
# 4958    43
# Name: tenure, Length: 2325, dtype: int64

# %%
save_model_predictor.leaderboard(test_data, silent=True)
# Out:
#                   model  score_test  score_val  pred_time_test  pred_time_val  \
# 0   WeightedEnsemble_L2    0.141075      0.166        1.059970       0.144760
# 1        NeuralNetTorch    0.140215      0.154        0.094260       0.007982
# 2            LightGBMXT    0.134194      0.140        0.046260       0.015626
# 3              CatBoost    0.132903      0.158        0.109694       0.015783
# 4               XGBoost    0.128602      0.146        0.470455       0.015637
# 5              LightGBM    0.126882      0.130        0.016013       0.017574
# 6       NeuralNetFastAI    0.118710      0.140        0.042746       0.024673
# 7         LightGBMLarge    0.113978      0.112        0.031163       0.015626
# 8        ExtraTreesGini    0.094624      0.118        0.832382       0.089621
# 9        ExtraTreesEntr    0.094194      0.106        0.964750       0.123610
# 10     RandomForestEntr    0.092903      0.116        0.936880       0.062725
# ...

# %% [markdown]
# ## Bringing it all together

# %%
test_data["predicted_tenure"] = y_pred

# %%
test_data["Dependents"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
test_data.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 185   1024-GUALD  Female              0     Yes         No       1
# 2715  0484-JPBRU    Male              0      No         No      41
# 3825  3620-EHIMZ  Female              0     Yes        Yes      52
# 1807  6910-HADCM  Female              0      No         No       1
# 132   8587-XYZSF    Male              0      No         No      67
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 185            No  No phone service             DSL                   No  ...
# 2715          Yes               Yes              No  No internet service  ...
# 3825          Yes                No              No  No internet service  ...
# 1807          Yes                No     Fiber optic                   No  ...
# 132           Yes                No             DSL                   No  ...
#
#               TechSupport          StreamingTV      StreamingMovies  \
# ...

# %%
test_data["error_values"] = abs(test_data["tenure"] - test_data["predicted_tenure"])

# %%
test_data.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 185   1024-GUALD  Female              0     Yes         No       1
# 2715  0484-JPBRU    Male              0      No         No      41
# 3825  3620-EHIMZ  Female              0     Yes        Yes      52
# 1807  6910-HADCM  Female              0      No         No       1
# 132   8587-XYZSF    Male              0      No         No      67
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 185            No  No phone service             DSL                   No  ...
# 2715          Yes               Yes              No  No internet service  ...
# 3825          Yes                No              No  No internet service  ...
# 1807          Yes                No     Fiber optic                   No  ...
# 132           Yes                No             DSL                   No  ...
#
#               StreamingTV      StreamingMovies        Contract  \
# ...

# %%
test_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 test_data.head()
#
# NameError: name 'test_data' is not defined
